# %% [markdown]
# # Revision: Scene setting
# - Global scene setting: Same to CuRobo, Moveit, etc.

# %% [markdown]
# #### 1. Initialize environment

# %%
from ri_motion_v5_package.init_scripts.init_ipython_setup import *
from ri_motion_v5_package.init_scripts.init_qt import *
from ri_motion_v5_package.mujoco_sim import *
from ri_motion_v5_package.kinematics import *
from ri_motion_v5_package.utility import *
from ri_motion_v5_package.qt import *
# trajectory tools 
from ri_motion_v5_package.traj_optimization.traj_utils import *
from ri_motion_v5_package.traj_optimization.traj_shaper import *
# gp tools 
from ri_motion_v5_package.gaussian_process.gp_utils import *
from ri_motion_v5_package.gaussian_process.kernels import rbf_kernel

from package.panda_env import * 

from PyQt5.QtWidgets import QApplication
app = QApplication(sys.argv)

from package.nfg import *
# Out:
# Basic packages initialized.
#  import numpy as np
#  import matplotlib.pyplot as plt
#  import scipy as sp
#  from PIL import Image
# [ipython] settings (retina, inline, qt) initialized.
# [numpy] settings initialized.
# [matplotlib] settings initialized.
# [qt] package initialized.
# Ready.

# %%
xml_path = merge_mjcfs(
    included_mjcf_files=[
        '../../asset/floor/floor_white_gray.xml',
        './asset/panda_inspire/panda_inspire_site_added.xml',
        './asset/bookshelf/bookshelf_base_thick.xml',
        './asset/bookshelf/bookshelf_deep_thick.xml',
        './asset/object/cylinder.xml',
    ],
    output_xml_path = 'xml/panda_bookshelf_scene.xml',
)
env = MuJoCoParser(rel_xml_path=xml_path,verbose=True)
# Out:
# [merge_mjcfs] Merging [5] MJCF files:
#   - [0] [../../asset/floor/floor_white_gray.xml]
#   - [1] [./asset/panda_inspire/panda_inspire_site_added.xml]
#   - [2] [./asset/bookshelf/bookshelf_base_thick.xml]
#   - [3] [./asset/bookshelf/bookshelf_deep_thick.xml]
#   - [4] [./asset/object/cylinder.xml]
# [merge_mjcfs] Saved merged XML to:[xml/panda_bookshelf_scene.xml]
#
# -----------------------------------------------------------------------------
# name:[scene] dt:[0.002] HZ:[500]
#  n_q:[26] n_v:[25] n_u:[7]
#  integrator:[IMPLICITFAST]
#
# Body information. n_body:[29]
#  [0/29] [world] parent:[world] mass:[0.00]kg
#  [1/29] [panda_base] parent:[world] mass:[0.00]kg
#  [2/29] [panda_link_0] parent:[panda_base] mass:[4.00]kg
#  [3/29] [panda_link_1] parent:[panda_link_0] mass:[3.00]kg
#  [4/29] [panda_link_2] parent:[panda_link_1] mass:[3.00]kg
#  [5/29] [panda_link_3] parent:[panda_link_2] mass:[2.00]kg
#  [6/29] [panda_link_4] parent:[panda_link_3] mass:[2.00]kg
#  [7/29] [panda_link_5] parent:[panda_link_4] mass:[2.00]kg
#  [8/29] [panda_link_6] parent:[panda_link_5] mass:[1.50]kg
#  [9/29] [panda_link_7] parent:[panda_link_6] mass:[0.50]kg
#  [10/29] [left_hand] parent:[panda_link_7] mass:[0.50]kg
#  [11/29] [robot0:hand] parent:[left_hand] mass:[0.00]kg
#  [12/29] [robot0:hand_offset] parent:[robot0:hand] mass:[0.00]kg
#  [13/29] [inspire_lh_palm] parent:[robot0:hand] mass:[1.10]kg
#  [14/29] [left_thumb_1] parent:[inspire_lh_palm] mass:[0.01]kg
#  [15/29] [left_thumb_2] parent:[left_thumb_1] mass:[0.04]kg
#  [16/29] [left_thumb_3] parent:[left_thumb_2] mass:[0.02]kg
#  [17/29] [left_thumb_4] parent:[left_thumb_3] mass:[0.01]kg
#  [18/29] [left_index_1] parent:[inspire_lh_palm] mass:[0.03]kg
#  [19/29] [left_index_2] parent:[left_index_1] mass:[0.01]kg
#  [20/29] [left_middle_1] parent:[inspire_lh_palm] mass:[0.03]kg
#  [21/29] [left_middle_2] parent:[left_middle_1] mass:[0.02]kg
#  [22/29] [left_ring_1] parent:[inspire_lh_palm] mass:[0.03]kg
#  [23/29] [left_ring_2] parent:[left_ring_1] mass:[0.01]kg
#  [24/29] [left_little_1] parent:[inspire_lh_palm] mass:[0.03]kg
#  [25/29] [left_little_2] parent:[left_little_1] mass:[0.01]kg
#  [26/29] [body_bookshelf_base_thick] parent:[world] mass:[58.60]kg
#  [27/29] [body_bookshelf_deep_thick] parent:[world] mass:[98.80]kg
#  [28/29] [body_cylinder] parent:[world] mass:[1.00]kg
# body_total_mass:[178.25]kg
#
# Geometry information. n_geom:[63]
#  [0/63] [floor] attached_body:[world]
#  [1/63] [panda_link_0_visual] attached_body:[panda_link_0]
#  [2/63] [panda_link_0_collision] attached_body:[panda_link_0]
#  [3/63] [panda_link_1_visual] attached_body:[panda_link_1]
#  [4/63] [panda_link_1_collision] attached_body:[panda_link_1]
#  [5/63] [panda_link_2_visual] attached_body:[panda_link_2]
#  [6/63] [panda_link_2_collision] attached_body:[panda_link_2]
#  [7/63] [panda_link_3_visual] attached_body:[panda_link_3]
#  [8/63] [panda_link_3_collision] attached_body:[panda_link_3]
#  [9/63] [panda_link_4_visual] attached_body:[panda_link_4]
#  [10/63] [panda_link_4_collision] attached_body:[panda_link_4]
#  [11/63] [panda_link_5_visual] attached_body:[panda_link_5]
#  [12/63] [panda_link_5_collision] attached_body:[panda_link_5]
#  [13/63] [panda_link_6_visual] attached_body:[panda_link_6]
#  [14/63] [panda_link_6_collision] attached_body:[panda_link_6]
#  [15/63] [panda_link_7_visual] attached_body:[panda_link_7]
#  [16/63] [panda_link_7_collision] attached_body:[panda_link_7]
#  [17/63] [None] attached_body:[inspire_lh_palm]
#  [18/63] [None] attached_body:[inspire_lh_palm]
#  [19/63] [None] attached_body:[left_thumb_2]
#  [20/63] [None] attached_body:[left_thumb_2]
#  [21/63] [None] attached_body:[left_thumb_3]
#  [22/63] [None] attached_body:[left_thumb_3]
#  [23/63] [None] attached_body:[left_thumb_4]
#  [24/63] [None] attached_body:[left_thumb_4]
#  [25/63] [None] attached_body:[left_thumb_4]
#  [26/63] [None] attached_body:[left_index_1]
#  [27/63] [None] attached_body:[left_index_1]
#  [28/63] [None] attached_body:[left_index_2]
#  [29/63] [None] attached_body:[left_index_2]
#  [30/63] [None] attached_body:[left_index_2]
#  [31/63] [None] attached_body:[left_middle_1]
#  [32/63] [None] attached_body:[left_middle_1]
#  [33/63] [None] attached_body:[left_middle_2]
#  [34/63] [None] attached_body:[left_middle_2]
#  [35/63] [None] attached_body:[left_middle_2]
#  [36/63] [None] attached_body:[left_ring_1]
#  [37/63] [None] attached_body:[left_ring_1]
#  [38/63] [None] attached_body:[left_ring_2]
#  [39/63] [None] attached_body:[left_ring_2]
#  [40/63] [None] attached_body:[left_ring_2]
#  [41/63] [None] attached_body:[left_little_1]
#  [42/63] [None] attached_body:[left_little_1]
#  [43/63] [None] attached_body:[left_little_2]
#  [44/63] [None] attached_body:[left_little_2]
#  [45/63] [None] attached_body:[left_little_2]
#  [46/63] [None] attached_body:[body_bookshelf_base_thick]
#  [47/63] [None] attached_body:[body_bookshelf_base_thick]
#  [48/63] [None] attached_body:[body_bookshelf_base_thick]
#  [49/63] [None] attached_body:[body_bookshelf_base_thick]
#  [50/63] [None] attached_body:[body_bookshelf_base_thick]
#  [51/63] [None] attached_body:[body_bookshelf_base_thick]
#  [52/63] [None] attached_body:[body_bookshelf_base_thick]
#  [53/63] [None] attached_body:[body_bookshelf_base_thick]
#  [54/63] [None] attached_body:[body_bookshelf_deep_thick]
#  [55/63] [None] attached_body:[body_bookshelf_deep_thick]
#  [56/63] [None] attached_body:[body_bookshelf_deep_thick]
#  [57/63] [None] attached_body:[body_bookshelf_deep_thick]
#  [58/63] [None] attached_body:[body_bookshelf_deep_thick]
#  [59/63] [None] attached_body:[body_bookshelf_deep_thick]
#  [60/63] [None] attached_body:[body_bookshelf_deep_thick]
#  [61/63] [None] attached_body:[body_bookshelf_deep_thick]
#  [62/63] [geom_cylinder] attached_body:[body_cylinder]
#
# Mesh information. n_mesh:[52]
#  [0/52] [panda_link0]
#  [1/52] [panda_link1]
#  [2/52] [panda_link2]
#  [3/52] [panda_link3]
#  [4/52] [panda_link4]
#  [5/52] [panda_link5]
#  [6/52] [panda_link6]
#  [7/52] [panda_link7]
#  [8/52] [panda_link0_vis]
#  [9/52] [panda_link1_vis]
#  [10/52] [panda_link2_vis]
#  [11/52] [panda_link3_vis]
#  [12/52] [panda_link4_vis]
#  [13/52] [panda_link5_vis]
#  [14/52] [panda_link6_vis]
#  [15/52] [panda_link7_vis]
#  [16/52] [panda_pedestal]
#  [17/52] [panda_hand]
#  [18/52] [panda_hand_vis]
#  [19/52] [panda_finger]
#  [20/52] [panda_finger_vis]
#  [21/52] [panda_finger_vis2]
#  [22/52] [base_link]
#  [23/52] [palm_force_sensor]
#  [24/52] [left_thumb_1]
#  [25/52] [left_thumb_2]
#  [26/52] [thumb_force_sensor_1]
#  [27/52] [left_thumb_3]
#  [28/52] [thumb_force_sensor_2]
#  [29/52] [left_thumb_4]
#  [30/52] [thumb_force_sensor_3]
#  [31/52] [thumb_force_sensor_4]
#  [32/52] [left_index_1]
#  [33/52] [index_force_sensor_1]
#  [34/52] [left_index_2]
#  [35/52] [index_force_sensor_2]
#  [36/52] [index_force_sensor_3]
#  [37/52] [left_middle_1]
#  [38/52] [middle_force_sensor_1]
#  [39/52] [left_middle_2]
#  [40/52] [middle_force_sensor_2]
#  [41/52] [middle_force_sensor_3]
#  [42/52] [left_ring_1]
#  [43/52] [ring_force_sensor_1]
#  [44/52] [left_ring_2]
#  [45/52] [ring_force_sensor_2]
#  [46/52] [ring_force_sensor_3]
#  [47/52] [left_little_1]
#  [48/52] [little_force_sensor_1]
#  [49/52] [left_little_2]
#  [50/52] [little_force_sensor_2]
#  [51/52] [little_force_sensor_3]
#
# Joint information. n_joint:[20]
#  [0/20] [panda_joint1] axis:[0. 0. 1.]
#  [1/20] [panda_joint2] axis:[0. 0. 1.]
#  [2/20] [panda_joint3] axis:[0. 0. 1.]
#  [3/20] [panda_joint4] axis:[0. 0. 1.]
#  [4/20] [panda_joint5] axis:[0. 0. 1.]
#  [5/20] [panda_joint6] axis:[0. 0. 1.]
#  [6/20] [panda_joint7] axis:[0. 0. 1.]
#  [7/20] [left_thumb_1_joint] axis:[0. 0. 1.]
#  [8/20] [left_thumb_2_joint] axis:[ 0.  0. -1.]
#  [9/20] [left_thumb_3_joint] axis:[ 0.  0. -1.]
#  [10/20] [left_thumb_4_joint] axis:[ 0.  0. -1.]
#  [11/20] [left_index_1_joint] axis:[0. 0. 1.]
#  [12/20] [left_index_2_joint] axis:[0. 0. 1.]
#  [13/20] [left_middle_1_joint] axis:[0. 0. 1.]
#  [14/20] [left_middle_2_joint] axis:[0. 0. 1.]
#  [15/20] [left_ring_1_joint] axis:[0. 0. 1.]
#  [16/20] [left_ring_2_joint] axis:[0. 0. 1.]
#  [17/20] [left_little_1_joint] axis:[0. 0. 1.]
#  [18/20] [left_little_2_joint] axis:[0. 0. 1.]
#  [19/20] [None] axis:[0. 0. 1.]
#
# Free joint information. n_free_joint:[1]
#  [0/1] [None] body_attached:[body_cylinder]
#
# Revolute joint information. n_rev_joint:[19]
#  [0/19] [panda_joint1] range:[-2.897]~[2.897]
#  [1/19] [panda_joint2] range:[-1.763]~[1.763]
#  [2/19] [panda_joint3] range:[-2.897]~[2.897]
#  [3/19] [panda_joint4] range:[-3.072]~[-0.070]
#  [4/19] [panda_joint5] range:[-2.897]~[2.897]
#  [5/19] [panda_joint6] range:[-0.018]~[3.752]
#  [6/19] [panda_joint7] range:[-2.897]~[2.897]
#  [7/19] [left_thumb_1_joint] range:[0.000]~[1.164]
#  [8/19] [left_thumb_2_joint] range:[0.000]~[0.586]
#  [9/19] [left_thumb_3_joint] range:[0.000]~[0.500]
#  [10/19] [left_thumb_4_joint] range:[0.000]~[3.140]
#  [11/19] [left_index_1_joint] range:[0.000]~[1.438]
#  [12/19] [left_index_2_joint] range:[0.000]~[3.140]
#  [13/19] [left_middle_1_joint] range:[0.000]~[1.438]
#  [14/19] [left_middle_2_joint] range:[0.000]~[3.140]
#  [15/19] [left_ring_1_joint] range:[0.000]~[1.438]
#  [16/19] [left_ring_2_joint] range:[0.000]~[3.140]
#  [17/19] [left_little_1_joint] range:[0.000]~[1.438]
#  [18/19] [left_little_2_joint] range:[0.000]~[3.140]
#
# Prismatic joint information. n_pri_joint:[0]
#
# Revolute+Prismatic joint information. n_rev_pri_joint:[19]
#  [0/19] [panda_joint1] range:[-2.897]~[2.897]
#  [1/19] [panda_joint2] range:[-1.763]~[1.763]
#  [2/19] [panda_joint3] range:[-2.897]~[2.897]
#  [3/19] [panda_joint4] range:[-3.072]~[-0.070]
#  [4/19] [panda_joint5] range:[-2.897]~[2.897]
#  [5/19] [panda_joint6] range:[-0.018]~[3.752]
#  [6/19] [panda_joint7] range:[-2.897]~[2.897]
#  [7/19] [left_thumb_1_joint] range:[0.000]~[1.164]
#  [8/19] [left_thumb_2_joint] range:[0.000]~[0.586]
#  [9/19] [left_thumb_3_joint] range:[0.000]~[0.500]
#  [10/19] [left_thumb_4_joint] range:[0.000]~[3.140]
#  [11/19] [left_index_1_joint] range:[0.000]~[1.438]
#  [12/19] [left_index_2_joint] range:[0.000]~[3.140]
#  [13/19] [left_middle_1_joint] range:[0.000]~[1.438]
#  [14/19] [left_middle_2_joint] range:[0.000]~[3.140]
#  [15/19] [left_ring_1_joint] range:[0.000]~[1.438]
#  [16/19] [left_ring_2_joint] range:[0.000]~[3.140]
#  [17/19] [left_little_1_joint] range:[0.000]~[1.438]
#  [18/19] [left_little_2_joint] range:[0.000]~[3.140]
#
# Active joint information. n_active_joint:[13]
#  [0/13] [panda_joint1] range:[-2.897]~[2.897]
#  [1/13] [panda_joint2] range:[-1.763]~[1.763]
#  [2/13] [panda_joint3] range:[-2.897]~[2.897]
#  [3/13] [panda_joint4] range:[-3.072]~[-0.070]
#  [4/13] [panda_joint5] range:[-2.897]~[2.897]
#  [5/13] [panda_joint6] range:[-0.018]~[3.752]
#  [6/13] [panda_joint7] range:[-2.897]~[2.897]
#  [7/13] [left_thumb_1_joint] range:[0.000]~[1.164]
#  [8/13] [left_thumb_2_joint] range:[0.000]~[0.586]
#  [9/13] [left_index_1_joint] range:[0.000]~[1.438]
#  [10/13] [left_middle_1_joint] range:[0.000]~[1.438]
#  [11/13] [left_ring_1_joint] range:[0.000]~[1.438]
#  [12/13] [left_little_1_joint] range:[0.000]~[1.438]
#
# Passive joint information. n_passive_joint:[6]
#  [0/6] [left_thumb_3_joint] range:[0.000]~[0.500]
#  [1/6] [left_thumb_4_joint] range:[0.000]~[3.140]
#  [2/6] [left_index_2_joint] range:[0.000]~[3.140]
#  [3/6] [left_middle_2_joint] range:[0.000]~[3.140]
#  [4/6] [left_ring_2_joint] range:[0.000]~[3.140]
#  [5/6] [left_little_2_joint] range:[0.000]~[3.140]
#
# Control information. n_ctrl:[7]
#  [0/7] [panda_torq_j1] range:[-80.000]~[80.000] gear:[1.00] type:[JOINT]
#  [1/7] [panda_torq_j2] range:[-80.000]~[80.000] gear:[1.00] type:[JOINT]
#  [2/7] [panda_torq_j3] range:[-80.000]~[80.000] gear:[1.00] type:[JOINT]
#  [3/7] [panda_torq_j4] range:[-80.000]~[80.000] gear:[1.00] type:[JOINT]
#  [4/7] [panda_torq_j5] range:[-80.000]~[80.000] gear:[1.00] type:[JOINT]
#  [5/7] [panda_torq_j6] range:[-12.000]~[12.000] gear:[1.00] type:[JOINT]
#  [6/7] [panda_torq_j7] range:[-12.000]~[12.000] gear:[1.00] type:[JOINT]
#
# Control-to-joint mapping.
#  [0/7] ctrl:[panda_torq_j1] qpos_idx:[0] qpos_name:[panda_joint1] qpos_range:[-2.897]~[2.897] qvel_idx:[0] type:[JOINT]
#  [1/7] ctrl:[panda_torq_j2] qpos_idx:[1] qpos_name:[panda_joint2] qpos_range:[-1.763]~[1.763] qvel_idx:[1] type:[JOINT]
#  [2/7] ctrl:[panda_torq_j3] qpos_idx:[2] qpos_name:[panda_joint3] qpos_range:[-2.897]~[2.897] qvel_idx:[2] type:[JOINT]
#  [3/7] ctrl:[panda_torq_j4] qpos_idx:[3] qpos_name:[panda_joint4] qpos_range:[-3.072]~[-0.070] qvel_idx:[3] type:[JOINT]
#  [4/7] ctrl:[panda_torq_j5] qpos_idx:[4] qpos_name:[panda_joint5] qpos_range:[-2.897]~[2.897] qvel_idx:[4] type:[JOINT]
#  [5/7] ctrl:[panda_torq_j6] qpos_idx:[5] qpos_name:[panda_joint6] qpos_range:[-0.018]~[3.752] qvel_idx:[5] type:[JOINT]
#  [6/7] ctrl:[panda_torq_j7] qpos_idx:[6] qpos_name:[panda_joint7] qpos_range:[-2.897]~[2.897] qvel_idx:[6] type:[JOINT]
#
# Joint-to-control mapping.
#  [0/20] joint:[panda_joint1] ctrl_idxs:[0] ctrl_names:['panda_torq_j1']
#  [1/20] joint:[panda_joint2] ctrl_idxs:[1] ctrl_names:['panda_torq_j2']
#  [2/20] joint:[panda_joint3] ctrl_idxs:[2] ctrl_names:['panda_torq_j3']
#  [3/20] joint:[panda_joint4] ctrl_idxs:[3] ctrl_names:['panda_torq_j4']
#  [4/20] joint:[panda_joint5] ctrl_idxs:[4] ctrl_names:['panda_torq_j5']
#  [5/20] joint:[panda_joint6] ctrl_idxs:[5] ctrl_names:['panda_torq_j6']
#  [6/20] joint:[panda_joint7] ctrl_idxs:[6] ctrl_names:['panda_torq_j7']
#  [7/20] joint:[left_thumb_1_joint] ctrl_idxs:[] ctrl_names:[]
#  [8/20] joint:[left_thumb_2_joint] ctrl_idxs:[] ctrl_names:[]
#  [9/20] joint:[left_thumb_3_joint] ctrl_idxs:[] ctrl_names:[]
#  [10/20] joint:[left_thumb_4_joint] ctrl_idxs:[] ctrl_names:[]
#  [11/20] joint:[left_index_1_joint] ctrl_idxs:[] ctrl_names:[]
#  [12/20] joint:[left_index_2_joint] ctrl_idxs:[] ctrl_names:[]
#  [13/20] joint:[left_middle_1_joint] ctrl_idxs:[] ctrl_names:[]
#  [14/20] joint:[left_middle_2_joint] ctrl_idxs:[] ctrl_names:[]
#  [15/20] joint:[left_ring_1_joint] ctrl_idxs:[] ctrl_names:[]
#  [16/20] joint:[left_ring_2_joint] ctrl_idxs:[] ctrl_names:[]
#  [17/20] joint:[left_little_1_joint] ctrl_idxs:[] ctrl_names:[]
#  [18/20] joint:[left_little_2_joint] ctrl_idxs:[] ctrl_names:[]
#  [19/20] joint:[None] ctrl_idxs:[] ctrl_names:[]
#
# Camera information. n_cam:[1]
#  [0/1] [panda_robotview] fov:[45.0] viewport:<MjrRect
#   bottom: 0
#   height: 600
#   left: 0
#   width: 800
# >
#
# Sensor information. n_sensor:[0]
#
# Site information. n_site:[7]
#  [0/7] [palm]
#  [1/7] [palm_top]
#  [2/7] [palm_front]
#  [3/7] [gcp]
#  [4/7] [gcp_top]
#  [5/7] [palm_palmar]
#  [6/7] [hand_contact_site]
# -----------------------------------------------------------------------------

# %% [markdown]
# #### 2. Intialize environment and generate smooth trajectory

# %%
# Configurations
panda_joints          = get_panda_joint_names() # check
inspire_joints        = get_inspire_joint_names() # check
inspire_active_joints = env.get_active_among_joints(inspire_joints)
p_cylinder_offset0    = get_p_offset_palm_to_cylinder()
qactive_inspire0      = get_qactive_inspire() # check
q_inspire0            = get_q_inspire(env) # check
q_pandas              = get_q_pandas_bookshelf() # check

# %%
""" TRAJECTORY 1"""
n_traj = 100
n_iter = 7
topk                = 5
trim_scale          = True
variance            = 1.0
length_scale_coef   = 0.5
contact_gain        = 10.0
motion_gain         = 5.0
q_min               = env.get_joint_mins(panda_joints)
q_max               = env.get_joint_maxs(panda_joints)
seed                = 3
# seed 1, 2 success among 0~4 (40%)
# seed 1, 2, 5, 6 success among 0~9 (40%)

# %%
""" TRAJECTORY 1"""
# set panda env 
width,height,x_offset,y_offset = 0.8,0.8,0.1,0.15
set_panda_bookshelf_env(
    env,panda_joints,inspire_joints,
    q_panda=q_pandas['right_2f'],q_inspire=q_inspire0, initialize_viewer=False)

# set anchors and get smoothed trajectory 
anchors = np.vstack((q_pandas['right_2f'],q_pandas['left_3f']))
L, times, traj_smt = get_smooth_traj_from_anchors(
    anchors = anchors,
    freq = 100,
    time = 5.0,
)
traj_update = traj_smt.copy()
# Get covariance matrix
K_chol, t_out = get_covariance_matrix_time_hilbert_space(
    times = times,
    L = L,
    length_scale_coef = length_scale_coef,
    variance = variance,
    kernel = rbf_kernel,
)
# loop: calculate costs, update traj, repeat
for iter_idx in range(n_iter):
    epsilon, traj_multidim = sample_epsilon_squash_trajs_multidim(
        traj=traj_update,
        K_chol=K_chol,
        n_traj=n_traj,
        dim=len(panda_joints),
        q_min=q_min,
        q_max=q_max,
        use_uniform=True,
        seed=seed, # different seed each iteration for more diverse sampling
        squash_margin=0.1,
    )
    # calculate scores
    motion_scores = calculate_motion_score(traj_multidim)
    contact_scores = np.zeros(n_traj)
    for traj_idx in range(n_traj):
        traj = traj_multidim[:,traj_idx,:]
        score_traj_single = np.zeros(L)
        for time_idx in range(L):
            env.forward(q=traj[time_idx], joint_names=panda_joints)
            # ========================================================
            T_palm = get_T_palm_panda_inspire(env)
            T_cylinder = view_in_world(T=p2t(p_cylinder_offset0),T_wl=T_palm)
            env.set_T('body_cylinder','base_body',T_cylinder)
            # ========================================================
            contact_info = env.get_contact_info()
            body_idxs = env.get_body_idxs_from_root_body_name('panda_link_1')
            # contact_info = filter_contact_info_with_body_idxs(contact_info, body_idxs=body_idxs)
            score_current_t = calculate_contact_score(contact_info)
            score_traj_single[time_idx] = score_current_t
        contact_scores[traj_idx] = score_traj_single.min()
    # if solved, terminalize
    if np.any(contact_scores  == 0.0):
        print_green(f"\n Contact-free trajectory found at iteration {iter_idx}, terminalizing optimization.")
        solved_idxs = np.where(contact_scores == 0.0)[0]
        best_solved_idx = solved_idxs[np.argmin(motion_scores[solved_idxs])]
        traj_update = traj_multidim[:,best_solved_idx,:]
        break
    # calculate gradient and update trajectory
    scores = contact_gain * contact_scores - motion_gain * motion_scores
    traj_update, gradient_fixed = update_traj_with_calculated_gradient(
        traj=traj_update,
        scores = scores,
        epsilon=epsilon,
        step_size=0.5,
    )
    print_yellow(f"Iteration {iter_idx+1}/{n_iter}, score_sum: {scores.sum():.4f}, score_max: {scores.max():.4f}, score_min: {scores.min():.4f}")
    seed += 1
traj_best = traj_update
# Out:
# [NFG] Generated smooth trajectory from anchors.
# [NFG] Generated covariance matrix for Hilbert space projection.
# [NFG] Sampled and squashed trajectories.
# [NFG] Updated trajectory with calculated gradient.
# Iteration 1/7, score_sum: -4147.7313, score_max: -8.7914, score_min: -292.7605
# [NFG] Sampled and squashed trajectories.
# [NFG] Updated trajectory with calculated gradient.
# Iteration 2/7, score_sum: -2729.6877, score_max: -5.8227, score_min: -196.0746
# [NFG] Sampled and squashed trajectories.
# [NFG] Updated trajectory with calculated gradient.
# Iteration 3/7, score_sum: -1947.8699, score_max: -3.5906, score_min: -39.1057
# [NFG] Sampled and squashed trajectories.
# [NFG] Updated trajectory with calculated gradient.
# Iteration 4/7, score_sum: -1779.0002, score_max: -4.0626, score_min: -153.4166
# [NFG] Sampled and squashed trajectories.
#
#  Contact-free trajectory found at iteration 4, terminalizing optimization.

# %%
# animate 
animate_bookshelf_env_traj(
    env                = env,
    mode_str           = "NFG_single_step",
    traj               = traj_best,
    panda_joints       = panda_joints,
    inspire_joints     = inspire_joints,
    q_start            = q_pandas['right_2f'],
    q_inspire0         = q_inspire0,
    p_cylinder_offset0 = p_cylinder_offset0,
    ubuntu_process_events_flag = True,
    app=app,
    cabinet_name = 'body_cabinet_half_closed_tall',
)
imshow(env.final_rgb_img)
print ("Done.")
# Out:
# Done.

# %%
def solve_nfg(
        nfg_env,
        robot_name,
        joints_use, 
        anchors, 
        n_traj                   = 20, 
        n_iter                   = 3,
        freq                     = 100,
        time                     = 5.0,
        length_scale_coef        = 0.5,
        variance                 = 0.3,
        kernel                   = rbf_kernel,
        contact_gain             = 10.0,
        motion_gain              = 5.0,
        topk                     = 5,
        trim_scale               = True,
        use_uniform              = True,
        seed                     = 42,
        squash_margin            = 0.1,
        attach_obj_name         = None
):
    """ 
    Generate Collision-free Trajectory using NFG.
    Args:
        - nfg_env: The NFG environment.
        - anchors: The anchor points for the trajectory.
        - freq: The frequency of the trajectory.
        - time: The duration of the trajectory.
        - length_scale_coef: The length scale coefficient for the NFG.
        - variance: The variance for the NFG.
        - kernel: The kernel type for the NFG.
        - contact_gain: The contact gain for the NFG.
    """
    # get joint min/max value 
    q_min = nfg_env.get_joint_mins(joints_use)
    q_max = nfg_env.get_joint_maxs(joints_use)
    # get body idxs for contact filtering
    body_idxs = env.get_body_idxs_from_root_body_name(robot_name)
    # get attach object transform 
    if attach_obj_name is not None:
        T_palm = env.get_T(type="site", name='rpalm')
        T_obj = env.get_T(type="body", name=attach_obj_name)
        T_palm_to_obj = np.linalg.inv(T_palm) @ T_obj
        body_idxs += env.get_body_idxs_from_root_body_name(attach_obj_name)

    L, times, traj_smt = get_smooth_traj_from_anchors(
        anchors = anchors,
        freq = freq,
        time = time,
    )
    traj_update = traj_smt.copy()
    K_chol, t_out = get_covariance_matrix_time_hilbert_space(
        times = times,
        L = L,
        length_scale_coef = length_scale_coef,
        variance = variance,
        kernel = kernel,
    )
    for iter_idx in range(n_iter):
        epsilon, traj_multidim = sample_epsilon_squash_trajs_multidim(
            traj=traj_update,
            K_chol=K_chol,
            n_traj=n_traj,
            dim=len(joints_use),
            q_min=q_min,
            q_max=q_max,
            use_uniform=use_uniform,
            seed=seed,
            squash_margin=squash_margin,
        )
        # calculate scores
        motion_scores = calculate_motion_score(traj_multidim)
        contact_scores = np.zeros(n_traj)
        for traj_idx in range(n_traj):
            traj = traj_multidim[:,traj_idx,:]
            score_traj_single = np.zeros(L)
            for time_idx in range(L):
                env.forward(q=traj[time_idx], joint_names=doosan_joints)
                if attach_obj_name is not None:
                    T_palm = env.get_T(type="site", name='rpalm')
                    T_obj = T_palm @ T_palm_to_obj
                    env.set_T(type="base_body", name=attach_obj_name, T=T_obj)
                contact_info = env.get_contact_info()
                contact_info = filter_contact_info_with_body_idxs(contact_info, body_idxs=body_idxs)
                score_current_t = calculate_contact_score(contact_info)
                score_traj_single[time_idx] = score_current_t
            contact_scores[traj_idx] = score_traj_single.min()
        # if solved, terminalize
        if np.any(contact_scores  == 0.0):
            print_green(f"\n Contact-free trajectory found at iteration {iter_idx}, terminalizing.")
            solved_idxs = np.where(contact_scores == 0.0)[0]
            best_solved_idx = solved_idxs[np.argmin(motion_scores[solved_idxs])]
            traj_update = traj_multidim[:,best_solved_idx,:]
            break
        # calculate gradient and update trajectory
        scores = contact_gain * contact_scores - motion_gain * motion_scores
        traj_update, gradient = update_traj_with_calculated_gradient(
            traj=traj_update,
            scores = scores,
            epsilon=epsilon,
            step_size=0.5,
        )
        print(f"Iteration {iter_idx+1}/{n_iter}, score_sum: {scores.sum():.4f}, score_max: {scores.max():.4f}, score_min: {scores.min():.4f}", end="")
    return traj_update
